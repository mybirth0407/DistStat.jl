# %%
using Printf, Statistics # load the packages
using CSV, DataFrames, CodecZlib, Mmap # packages for data reading. GZip is used to read the gzipped text file.

# package for one-hot encoding
using Flux: onehot

# %%
using CUDA, Adapt

# %%
# group_info.txt, methylation_data.txt, sample_data.txt
# df_sample = DataFrame(CSV.File("LiverCancer_methylation/sample_data.txt"));
df_sample = DataFrame(CSV.File("ko/sample_data2.txt"));
